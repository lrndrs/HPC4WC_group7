# %% [markdown]
# ### Stencils

# %%
import numpy as np
from functions.create_field import get_random_field
from functions.update_halo import update_halo

# %% [markdown]
# Define your field here:

# %%
dim = 3
nx = 10
ny = 10
nz = 10
num_halo = 1

# %% [markdown]
# Function to create the field (filled with random numbers from 0 to 1)

# %%
field = get_random_field(dim, nx, ny, nz)
# Out:
# dim = 3; nx = 10; ny = 10; nz = 10

# %% [markdown]
# Function to update the halo (border condition continues)

# %%
field = update_halo(dim , field, num_halo)

# %%
field
# Out:
# array([[[3.16511113e-01, 8.96454926e-01, 4.33304306e-01, 4.80671789e-01,
#          6.25270116e-01, 2.46187380e-01, 3.27281500e-01, 3.53568478e-01,
#          3.16511113e-01, 8.96454926e-01],
#         [5.53951217e-01, 3.49708031e-01, 3.29884082e-01, 3.58786406e-01,
#          4.24934285e-01, 7.81511806e-01, 7.82654087e-01, 8.76365857e-01,
#          5.53951217e-01, 3.49708031e-01],
#         [1.05264260e-01, 9.53234338e-01, 5.58764685e-01, 7.66585614e-01,
#          6.43763454e-01, 6.57067742e-01, 1.21225761e-01, 5.78516963e-01,
#          1.05264260e-01, 9.53234338e-01],
#         [2.52085002e-01, 4.95126593e-01, 8.06938346e-01, 4.99632105e-01,
#          3.06159442e-01, 7.39157263e-01, 2.20188548e-01, 4.70236654e-01,
#          2.52085002e-01, 4.95126593e-01],
#         [3.56508238e-01, 5.76743421e-01, 1.58167772e-01, 6.48859208e-01,
#          4.74275926e-01, 7.41657306e-01, 8.54882819e-01, 5.00338861e-02,
#          3.56508238e-01, 5.76743421e-01],
# ...
